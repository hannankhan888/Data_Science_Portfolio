# %% [markdown]
# # Bike-Share Data Concatenation
# >Author: Hannan Khan
# >Last Updated: 02/15/2022
#
# This script is for concatenating the bike-share data.

# %%
import pandas as pd

# %% [markdown]
# # Look At Last Year's (2021) Data
# How much data does it contain?

# %%
pd.read_csv(r'D:\Datasets\Divvy_Trips_Data\Divvy_Trips_2021\202101-divvy-tripdata.csv')
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      E19E6F1B8D4C42ED  electric_bike  2021-01-23 16:14:19
# 1      DC88F20C2C55F27F  electric_bike  2021-01-27 18:43:08
# 2      EC45C94683FE3F27  electric_bike  2021-01-21 22:35:54
# 3      4FA453A75AE377DB  electric_bike  2021-01-07 13:31:13
# 4      BE5E8EB4E7263A0B  electric_bike  2021-01-23 02:24:02
# ...                 ...            ...                  ...
# 96829  B1A5336E1412D8BF   classic_bike  2021-01-19 19:03:17
# 96830  57EA5CB7DCD75F90   classic_bike  2021-01-05 18:42:27
# 96831  815B319A078CC984   classic_bike  2021-01-07 17:59:47
# 96832  6DB04151565CEE63   classic_bike  2021-01-06 19:20:31
# 96833  8008C9C998083A1A    docked_bike  2021-01-17 13:20:02
#
#                   ended_at               start_station_name start_station_id  \
# 0      2021-01-23 16:24:44       California Ave & Cortez St            17660
# 1      2021-01-27 18:47:12       California Ave & Cortez St            17660
# ...

# %% [markdown]
# # Script To Load & Concatenate All 2021 DataFrames Together

# %%
df = pd.read_csv(r'D:\Datasets\Divvy_Trips_Data\Divvy_Trips_2021\202101-divvy-tripdata.csv')

# we use a combo of f-strings and r-strings
for month in range(2,13):
    if month < 10:
        f = fr'D:\Datasets\Divvy_Trips_Data\Divvy_Trips_2021\20210{month}-divvy-tripdata.csv'
    else:
        f = fr'D:\Datasets\Divvy_Trips_Data\Divvy_Trips_2021\2021{month}-divvy-tripdata.csv'
    df2 = pd.read_csv(f)
    df = pd.concat([df, df2], ignore_index=True)
df
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        E19E6F1B8D4C42ED  electric_bike  2021-01-23 16:14:19
# 1        DC88F20C2C55F27F  electric_bike  2021-01-27 18:43:08
# 2        EC45C94683FE3F27  electric_bike  2021-01-21 22:35:54
# 3        4FA453A75AE377DB  electric_bike  2021-01-07 13:31:13
# 4        BE5E8EB4E7263A0B  electric_bike  2021-01-23 02:24:02
# ...                   ...            ...                  ...
# 5595058  847431F3D5353AB7  electric_bike  2021-12-12 13:36:55
# 5595059  CF407BBC3B9FAD63  electric_bike  2021-12-06 19:37:50
# 5595060  60BB69EBF5440E92  electric_bike  2021-12-02 08:57:04
# 5595061  C414F654A28635B8  electric_bike  2021-12-13 09:00:26
# 5595062  37AC57E34B2E7E97   classic_bike  2021-12-13 08:45:32
#
#                     ended_at           start_station_name start_station_id  \
# 0        2021-01-23 16:24:44   California Ave & Cortez St            17660
# ...

# %%
df.to_csv(r'D:\Datasets\Divvy_Trips_Data\Divvy_Trips_2021\2021_all_data.csv')

# %% [markdown]
# # While We Are Here, Let's Concatenate All Past 3 Years Of Data In Case We Need It Later
# ## 2020

# %%
pd.read_csv(r'D:\Datasets\Divvy_Trips_Data\Divvy_Trips_2020\Divvy_Trips_2020_Q1.csv')
# Out:
#                  ride_id rideable_type           started_at  \
# 0       EACB19130B0CDA4A   docked_bike  2020-01-21 20:06:59
# 1       8FED874C809DC021   docked_bike  2020-01-30 14:22:39
# 2       789F3C21E472CA96   docked_bike  2020-01-09 19:29:26
# 3       C9A388DAC6ABF313   docked_bike  2020-01-06 16:17:07
# 4       943BC3CBECCFD662   docked_bike  2020-01-30 08:37:16
# ...                  ...           ...                  ...
# 426882  ADDAA33CEBCAE733   docked_bike  2020-03-10 10:40:06
# 426883  82B10FA3994BC66A   docked_bike  2020-03-07 15:25:55
# 426884  AA0D5AAA0B59C8AA   docked_bike  2020-03-01 13:12:38
# 426885  3296360A7BC20FB8   docked_bike  2020-03-07 18:02:45
# 426886  064EC7698E4FF9B3   docked_bike  2020-03-08 13:03:57
#
#                    ended_at         start_station_name  start_station_id  \
# 0       2020-01-21 20:14:30   Western Ave & Leland Ave               239
# 1       2020-01-30 14:26:22    Clark St & Montrose Ave               234
# ...

# %%
# contains data for the first quarter:
df = pd.read_csv(r'D:\Datasets\Divvy_Trips_Data\Divvy_Trips_2020\Divvy_Trips_2020_Q1.csv')

for month in range(4,13):
    if month < 10:
        f = fr'D:\Datasets\Divvy_Trips_Data\Divvy_Trips_2020\20200{month}-divvy-tripdata.csv'
    else:
        f = fr'D:\Datasets\Divvy_Trips_Data\Divvy_Trips_2020\2020{month}-divvy-tripdata.csv'
    df2 = pd.read_csv(f)
    df = pd.concat([df,df2], ignore_index=True)
df
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        EACB19130B0CDA4A    docked_bike  2020-01-21 20:06:59
# 1        8FED874C809DC021    docked_bike  2020-01-30 14:22:39
# 2        789F3C21E472CA96    docked_bike  2020-01-09 19:29:26
# 3        C9A388DAC6ABF313    docked_bike  2020-01-06 16:17:07
# 4        943BC3CBECCFD662    docked_bike  2020-01-30 08:37:16
# ...                   ...            ...                  ...
# 3541678  4631EE956BCEA738   classic_bike  2020-12-19 13:59:33
# 3541679  D17CBEDEA8DBDFF6  electric_bike  2020-12-20 15:48:41
# 3541680  447A6C67E9AF962E    docked_bike  2020-12-02 16:59:58
# 3541681  F558C17E95751C62  electric_bike  2020-12-20 18:06:52
# 3541682  E1888F4B274EEA12  electric_bike  2020-12-03 09:43:42
#
#                     ended_at        start_station_name start_station_id  \
# 0        2020-01-21 20:14:30  Western Ave & Leland Ave            239.0
# 1        2020-01-30 14:26:22   Clark St & Montrose Ave            234.0
# ...

# %%
df.to_csv(r'D:\Datasets\Divvy_Trips_Data\Divvy_Trips_2020\2020_all_data.csv')

# %% [markdown]
# ## 2019

# %%
pd.read_csv(r'D:\Datasets\Divvy_Trips_Data\Divvy_Trips_2019\Divvy_Trips_2019_Q1.csv')
# Out:
#          trip_id           start_time             end_time  bikeid  \
# 0       21742443  2019-01-01 00:04:37  2019-01-01 00:11:07    2167
# 1       21742444  2019-01-01 00:08:13  2019-01-01 00:15:34    4386
# 2       21742445  2019-01-01 00:13:23  2019-01-01 00:27:12    1524
# 3       21742446  2019-01-01 00:13:45  2019-01-01 00:43:28     252
# 4       21742447  2019-01-01 00:14:52  2019-01-01 00:20:56    1170
# ...          ...                  ...                  ...     ...
# 365064  22178524  2019-03-31 23:51:32  2019-04-01 00:04:09    1501
# 365065  22178525  2019-03-31 23:52:37  2019-03-31 23:58:09    3270
# 365066  22178526  2019-03-31 23:52:38  2019-04-01 00:06:44    3584
# 365067  22178527  2019-03-31 23:53:08  2019-03-31 23:56:06    4384
# 365068  22178528  2019-03-31 23:53:48  2019-04-01 00:01:16    5589
#
#        tripduration  from_station_id                    from_station_name  \
# 0             390.0              199               Wabash Ave & Grand Ave
# ...

# %%
# this years data is split into quarters instead of by month.
df = pd.read_csv(r'D:\Datasets\Divvy_Trips_Data\Divvy_Trips_2019\Divvy_Trips_2019_Q1.csv')

for quarter in range(2,5):
    f = fr'D:\Datasets\Divvy_Trips_Data\Divvy_Trips_2019\Divvy_Trips_2019_Q{quarter}.csv'
    df2 = pd.read_csv(f)
    df = pd.concat([df,df2], ignore_index=True)
df
# Out:
#             trip_id           start_time             end_time  bikeid  \
# 0        21742443.0  2019-01-01 00:04:37  2019-01-01 00:11:07  2167.0
# 1        21742444.0  2019-01-01 00:08:13  2019-01-01 00:15:34  4386.0
# 2        21742445.0  2019-01-01 00:13:23  2019-01-01 00:27:12  1524.0
# 3        21742446.0  2019-01-01 00:13:45  2019-01-01 00:43:28   252.0
# 4        21742447.0  2019-01-01 00:14:52  2019-01-01 00:20:56  1170.0
# ...             ...                  ...                  ...     ...
# 3817999  25962900.0  2019-12-31 23:56:13  2020-01-01 00:15:45  2196.0
# 3818000  25962901.0  2019-12-31 23:56:34  2020-01-01 00:22:08  4877.0
# 3818001  25962902.0  2019-12-31 23:57:05  2020-01-01 00:05:46   863.0
# 3818002  25962903.0  2019-12-31 23:57:11  2020-01-01 00:05:45  2637.0
# 3818003  25962904.0  2019-12-31 23:57:17  2019-12-31 23:59:18  5930.0
#
#         tripduration  from_station_id                    from_station_name  \
# ...

# %%
df.to_csv(r'D:\Datasets\Divvy_Trips_Data\Divvy_Trips_2019\2019_all_data.csv')
