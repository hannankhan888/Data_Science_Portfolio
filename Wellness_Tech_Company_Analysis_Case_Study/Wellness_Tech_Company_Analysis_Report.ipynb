# %% [markdown]
# # Wellness Tech Company Analysis Report
# > Author: Hannan Khan
# > Last Updated: 2022-02-25 07:09:30
#
# ## Table Of Contents:
# * [Current Status](#Current-Status)
# * [Business Task](#Business-Task)
# * [Data Sources](#Data-Sources)
# * [Data Cleaning](#Data-Cleaning)
#     * [Loading Libraries](#Loading-Libraries)
#     * [Creating Database Objects](#Creating-Database-Objects)
#     * [Common Query Functions](#Common-Query-Functions)
# * [Data Preparation-Processing](#Data-Preparation-Processing)
#     * [Looking At All Tables](#Looking-At-All-Tables,-Their-Columns-&-Datatypes)
# * [Analysis](#Analysis)
#     * [Analysis Summary](#Analysis-Summary)
# * [Actions](#Actions)
# * [Appendix](#Appendix)
#     * [Definitions](#Definitions)
#     * [Files Used](#Files-Used)

# %% [markdown]
# ## Current Status
# The company `Bellabeat` creates health-focused smart technology products for women. The data gathered from these products includes activity, sleep, stress, and reproductive health data.
#
# The company currently invests in traditional advertising media. The co-founder believes that an analysis of smart technology usage data will allow for more opportunities of business growth.
#
# ## Business Task
# The current goal of `Bellabeat` is to gain insight into how people use smart devices. These insights can then be used to idenitfy potential trends within `Bellabeat` customers' data. The insights will also be used to inform the company's marketing strategy.
# The **goal of this report is to analyze non-Bellabeat smart device usage data to gain insights about smart device usage trends.**
#
# ## Data Sources
# The data is publicly available [here](https://www.kaggle.com/arashnic/fitbit). The data was collected during `03/2016 - 05/2016` through a anonymized survey program bywhich `30` respondents submitted their personal Fitbit data. The data is made available using the [Creative Commons License](https://creativecommons.org/publicdomain/zero/1.0/).
# The dataset contains various files, each of which can be characterized temporally by day, hour, or minute. The files include data on:
#
# * Calories
# * Intensities
# * Steps
# * Sleep
# * and more...
#
# The dataset in question is:
#
# * *Reliable*: From a distributed anonymized survey.
# * *Original*: This is novel data.
# * *Comprehensive*: This data covers enough features for us to analyze the smart device usage of 30 users.
# * _**NOT** Current_: Collected during `03/2016 - 05/2016`.
# * *Cited*: see [Data Sources](#data-sources)
#
# This dataset was analyzed using SQL, specifically, Python's sqlite3 library. The notebook for creating and loading a database with the dataset's files can be found [here](https://github.com/hannankhan888/Data_Science_Portfolio/tree/main/Wellness_Tech_Company_Analysis_Case_Study/Database_Creator_Loader.ipynb).

# %% [markdown]
# ## Data Cleaning
# The data was concatenated into `daily`, `minuteNarrow`, `minuteWide`, and `hourly` SQL tables using [this](https://github.com/hannankhan888/Data_Science_Portfolio/tree/main/Wellness_Tech_Company_Analysis_Case_Study/Data_Concatenation.ipynb) notebook.
# The data was already cleaned using the aforementioned notebook. So, we will instead use this section of the report to initialize all variables and functions.
#
# ### Loading Libraries

# %%
import sqlite3 as sql
from pprint import pprint
import os

# %% [markdown]
# ### Creating Database Objects

# %%
data_dir = r"D:\Datasets\Fitabase_Data"
db_dir = data_dir + r"\\database.db"

# create a connection and cursor to the database:
db_con = sql.connect(db_dir)
cur = db_con.cursor()

# test if connection works:
cur.execute("SELECT name FROM sqlite_master WHERE type='table';")
print("Tables:")
pprint(cur.fetchall())
# Out:
# Tables:
# [('daily',), ('minuteNarrow',), ('minuteWide',), ('hourly',)]

# %% [markdown]
# ### Common Query Functions

# %%
def get_tables_and_cols(cur):
    """ Gets the tables and columns from a cursor object.
    RETURNS tables_cols: a list of tuples with table name and column name.
            tables_dict: a dict where every key is a table name and every
                        value is a list of column names."""
    get_cols = f"""
    SELECT
      m.name,
      p.name
    FROM 
      sqlite_master AS m
    JOIN 
      pragma_table_info(m.name) AS p
    WHERE m.type='table'
    """
    cur.execute(get_cols)
    tables_cols = cur.fetchall()

    # create tables dictionary:
    tables_set = set()
    tables_dict = {}
    for table,_ in tables_cols:
        tables_set.add(table)
    for table in tables_set:
        tables_dict[table] = []
        for tbl,col in tables_cols:
            if table==tbl:
                tables_dict[table].append(col)
    return tables_dict, tables_cols

def get_database_table_count(cur):
    """ Prints the number of tables from a cursor object."""
    
    cur.execute("SELECT COUNT(*) FROM sqlite_master WHERE type = 'table';")
    print("How many tables do we have:", cur.fetchall())

def get_all_pragma_tables(cur):
    """ Gets the pragma (schema) tables for all tables from the cursor object.
    Prints result as a table."""
    
    all_pragma_tables_query = """
    SELECT 
      m.name as table_name,
      p.*
    FROM 
      sqlite_master AS m
    JOIN 
      pragma_table_info(m.name) AS p
    ORDER BY 
      m.name, 
      p.cid
    """

    cur.execute(all_pragma_tables_query)
    print("|:::::::::::::::::::::::::::::::::::::ALL PRAGMA TABLES::::::::::::::::::::::::::::::::::::::::|")
    print("|{:30}|{:3}|{:25}|{:10}|{:7}|{:11}|{:2}|".format("table_name", "cid", "col_name", "type", "notnull", "dflt_values", "pk"))
    print("|",":"*92,"|")
    for blah in cur.fetchall():
        blah = [str(i) for i in blah]
        print("|{:30}|{:3}|{:25}|{:10}|{:7}|{:11}|{:2}|".format(blah[0], blah[1], blah[2], blah[3], blah[4], blah[5], blah[6]))

def get_table_col_example(cur):
    """ Gets the table name, column name, and an example data point from
    that column.
    Prints results in neat table."""
    
    _, tables_cols = get_tables_and_cols(cur)

    print("|{:30}|{:25}|{:25}|".format("TABLE", "COLUMN", "EXAMPLE"))
    print("|","="*80,"|")
    for table,col in tables_cols:
        get_example = f"""
        SELECT {col}
        FROM {table}
        LIMIT 1
        """
        cur.execute(get_example)
        print("|{:30}|{:25}|{:25}|".format(table, col, str(cur.fetchall()[0][0])))

def get_tables_with_num_rows(cur):
    """ Prints table names along with the number of rows in that table."""
    
    tables_dict, tables_cols = get_tables_and_cols(cur)
    print("Number of rows in each table:")
    for table in sorted(tables_dict.keys()):
        cur.execute(f"SELECT COUNT(*) FROM {table}")
        print("{:32}{:>15}".format(table, str(cur.fetchall())))

def get_table_cols_with_dtypes(cur, table_name):
    """Prints the table column names, along with their associated data types."""
    
    get_new_table_cols = f"""
    WITH minuteTables AS (
    SELECT m.name
    FROM 
      sqlite_master AS m
    JOIN 
      pragma_table_info(m.name) AS p
    WHERE
      m.name = '{table_name}'
    GROUP BY
      m.name
    )
    SELECT col AS columns, type AS dtype
    FROM (
        SELECT pti.name AS col, pti.type AS type
        FROM minuteTables AS t CROSS JOIN pragma_table_info(t.name) AS pti
        GROUP BY col
    );"""

    cur.execute(get_new_table_cols)
    print(f"`{table_name}` table cols:")
    pprint(cur.fetchall())

# %% [markdown]
# ## Data Preparation-Processing
# The data was prepared and preprocessed using the [data concatenation notebook](https://github.com/hannankhan888/Data_Science_Portfolio/tree/main/Wellness_Tech_Company_Analysis_Case_Study/Data_Concatenation.ipynb). The only feature engineering completed was that of adding a new "TotalActiveMinutes" column to the `daily` table in the database.
# We will instead use this section to get an overall view of the database and its tables.

# %% [markdown]
# ### Looking At All Tables, Their Columns & Datatypes

# %%
get_all_pragma_tables(cur)
# Out:
# |:::::::::::::::::::::::::::::::::::::ALL PRAGMA TABLES::::::::::::::::::::::::::::::::::::::::|
# |table_name                    |cid|col_name                 |type      |notnull|dflt_values|pk|
# | :::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::: |
# |daily                         |0  |Id                       |INT       |0      |None       |0 |
# |daily                         |1  |ActivityDate             |NUM       |0      |None       |0 |
# |daily                         |2  |TotalSteps               |INT       |0      |None       |0 |
# |daily                         |3  |TotalDistance            |NUM       |0      |None       |0 |
# |daily                         |4  |TrackerDistance          |NUM       |0      |None       |0 |
# |daily                         |5  |LoggedActivitiesDistance |NUM       |0      |None       |0 |
# |daily                         |6  |VeryActiveDistance       |NUM       |0      |None       |0 |
# |daily                         |7  |ModeratelyActiveDistance |NUM       |0      |None       |0 |
# |daily                         |8  |LightActiveDistance      |NUM       |0      |None       |0 |
# |daily                         |9  |SedentaryActiveDistance  |NUM       |0      |None       |0 |
# |daily                         |10 |VeryActiveMinutes        |INT       |0      |None       |0 |
# |daily                         |11 |FairlyActiveMinutes      |INT       |0      |None       |0 |
# |daily                         |12 |LightlyActiveMinutes     |INT       |0      |None       |0 |
# |daily                         |13 |SedentaryMinutes         |INT       |0      |None       |0 |
# |daily                         |14 |Calories                 |INT       |0      |None       |0 |
# |daily                         |15 |TotalMinutesAsleep       |INT       |0      |None       |0 |
# |daily                         |16 |TotalSleepRecords        |INT       |0      |None       |0 |
# |daily                         |17 |TotalTimeInBed           |INT       |0      |None       |0 |
# |daily                         |18 |TotalActiveDistance      |INT       |0      |None       |0 |
# |daily                         |19 |TotalActiveMinutes       |INT       |0      |None       |0 |
# |hourly                        |0  |Id                       |INT       |0      |None       |0 |
# |hourly                        |1  |ActivityHour             |NUM       |0      |None       |0 |
# |hourly                        |2  |Calories                 |INT       |0      |None       |0 |
# |hourly                        |3  |AverageIntensity         |NUM       |0      |None       |0 |
# |hourly                        |4  |TotalIntensity           |INT       |0      |None       |0 |
# |hourly                        |5  |StepTotal                |INT       |0      |None       |0 |
# |hourly                        |6  |Calories00               |NUM       |0      |None       |0 |
# |hourly                        |7  |Calories01               |NUM       |0      |None       |0 |
# |hourly                        |8  |Calories02               |NUM       |0      |None       |0 |
# |hourly                        |9  |Calories03               |NUM       |0      |None       |0 |
# |hourly                        |10 |Calories04               |NUM       |0      |None       |0 |
# |hourly                        |11 |Calories05               |NUM       |0      |None       |0 |
# |hourly                        |12 |Calories06               |NUM       |0      |None       |0 |
# |hourly                        |13 |Calories07               |NUM       |0      |None       |0 |
# |hourly                        |14 |Calories08               |NUM       |0      |None       |0 |
# |hourly                        |15 |Calories09               |NUM       |0      |None       |0 |
# |hourly                        |16 |Calories10               |NUM       |0      |None       |0 |
# |hourly                        |17 |Calories11               |NUM       |0      |None       |0 |
# |hourly                        |18 |Calories12               |NUM       |0      |None       |0 |
# |hourly                        |19 |Calories13               |NUM       |0      |None       |0 |
# |hourly                        |20 |Calories14               |NUM       |0      |None       |0 |
# |hourly                        |21 |Calories15               |NUM       |0      |None       |0 |
# |hourly                        |22 |Calories16               |NUM       |0      |None       |0 |
# |hourly                        |23 |Calories17               |NUM       |0      |None       |0 |
# |hourly                        |24 |Calories18               |NUM       |0      |None       |0 |
# |hourly                        |25 |Calories19               |NUM       |0      |None       |0 |
# |hourly                        |26 |Calories20               |NUM       |0      |None       |0 |
# |hourly                        |27 |Calories21               |NUM       |0      |None       |0 |
# |hourly                        |28 |Calories22               |NUM       |0      |None       |0 |
# |hourly                        |29 |Calories23               |NUM       |0      |None       |0 |
# |hourly                        |30 |Calories24               |NUM       |0      |None       |0 |
# |hourly                        |31 |Calories25               |NUM       |0      |None       |0 |
# |hourly                        |32 |Calories26               |NUM       |0      |None       |0 |
# |hourly                        |33 |Calories27               |NUM       |0      |None       |0 |
# |hourly                        |34 |Calories28               |NUM       |0      |None       |0 |
# |hourly                        |35 |Calories29               |NUM       |0      |None       |0 |
# |hourly                        |36 |Calories30               |NUM       |0      |None       |0 |
# |hourly                        |37 |Calories31               |NUM       |0      |None       |0 |
# |hourly                        |38 |Calories32               |NUM       |0      |None       |0 |
# |hourly                        |39 |Calories33               |NUM       |0      |None       |0 |
# |hourly                        |40 |Calories34               |NUM       |0      |None       |0 |
# |hourly                        |41 |Calories35               |NUM       |0      |None       |0 |
# |hourly                        |42 |Calories36               |NUM       |0      |None       |0 |
# |hourly                        |43 |Calories37               |NUM       |0      |None       |0 |
# |hourly                        |44 |Calories38               |NUM       |0      |None       |0 |
# |hourly                        |45 |Calories39               |NUM       |0      |None       |0 |
# |hourly                        |46 |Calories40               |NUM       |0      |None       |0 |
# |hourly                        |47 |Calories41               |NUM       |0      |None       |0 |
# |hourly                        |48 |Calories42               |NUM       |0      |None       |0 |
# |hourly                        |49 |Calories43               |NUM       |0      |None       |0 |
# |hourly                        |50 |Calories44               |NUM       |0      |None       |0 |
# |hourly                        |51 |Calories45               |NUM       |0      |None       |0 |
# |hourly                        |52 |Calories46               |NUM       |0      |None       |0 |
# |hourly                        |53 |Calories47               |NUM       |0      |None       |0 |
# |hourly                        |54 |Calories48               |NUM       |0      |None       |0 |
# |hourly                        |55 |Calories49               |NUM       |0      |None       |0 |
# |hourly                        |56 |Calories50               |NUM       |0      |None       |0 |
# |hourly                        |57 |Calories51               |NUM       |0      |None       |0 |
# |hourly                        |58 |Calories52               |NUM       |0      |None       |0 |
# |hourly                        |59 |Calories53               |NUM       |0      |None       |0 |
# |hourly                        |60 |Calories54               |NUM       |0      |None       |0 |
# |hourly                        |61 |Calories55               |NUM       |0      |None       |0 |
# |hourly                        |62 |Calories56               |NUM       |0      |None       |0 |
# |hourly                        |63 |Calories57               |NUM       |0      |None       |0 |
# |hourly                        |64 |Calories58               |NUM       |0      |None       |0 |
# |hourly                        |65 |Calories59               |NUM       |0      |None       |0 |
# |hourly                        |66 |Intensity00              |INT       |0      |None       |0 |
# |hourly                        |67 |Intensity01              |INT       |0      |None       |0 |
# |hourly                        |68 |Intensity02              |INT       |0      |None       |0 |
# |hourly                        |69 |Intensity03              |INT       |0      |None       |0 |
# |hourly                        |70 |Intensity04              |INT       |0      |None       |0 |
# |hourly                        |71 |Intensity05              |INT       |0      |None       |0 |
# |hourly                        |72 |Intensity06              |INT       |0      |None       |0 |
# |hourly                        |73 |Intensity07              |INT       |0      |None       |0 |
# |hourly                        |74 |Intensity08              |INT       |0      |None       |0 |
# |hourly                        |75 |Intensity09              |INT       |0      |None       |0 |
# |hourly                        |76 |Intensity10              |INT       |0      |None       |0 |
# |hourly                        |77 |Intensity11              |INT       |0      |None       |0 |
# |hourly                        |78 |Intensity12              |INT       |0      |None       |0 |
# |hourly                        |79 |Intensity13              |INT       |0      |None       |0 |
# |hourly                        |80 |Intensity14              |INT       |0      |None       |0 |
# |hourly                        |81 |Intensity15              |INT       |0      |None       |0 |
# |hourly                        |82 |Intensity16              |INT       |0      |None       |0 |
# |hourly                        |83 |Intensity17              |INT       |0      |None       |0 |
# |hourly                        |84 |Intensity18              |INT       |0      |None       |0 |
# |hourly                        |85 |Intensity19              |INT       |0      |None       |0 |
# |hourly                        |86 |Intensity20              |INT       |0      |None       |0 |
# |hourly                        |87 |Intensity21              |INT       |0      |None       |0 |
# |hourly                        |88 |Intensity22              |INT       |0      |None       |0 |
# |hourly                        |89 |Intensity23              |INT       |0      |None       |0 |
# |hourly                        |90 |Intensity24              |INT       |0      |None       |0 |
# |hourly                        |91 |Intensity25              |INT       |0      |None       |0 |
# |hourly                        |92 |Intensity26              |INT       |0      |None       |0 |
# |hourly                        |93 |Intensity27              |INT       |0      |None       |0 |
# |hourly                        |94 |Intensity28              |INT       |0      |None       |0 |
# |hourly                        |95 |Intensity29              |INT       |0      |None       |0 |
# |hourly                        |96 |Intensity30              |INT       |0      |None       |0 |
# |hourly                        |97 |Intensity31              |INT       |0      |None       |0 |
# |hourly                        |98 |Intensity32              |INT       |0      |None       |0 |
# |hourly                        |99 |Intensity33              |INT       |0      |None       |0 |
# |hourly                        |100|Intensity34              |INT       |0      |None       |0 |
# |hourly                        |101|Intensity35              |INT       |0      |None       |0 |
# |hourly                        |102|Intensity36              |INT       |0      |None       |0 |
# |hourly                        |103|Intensity37              |INT       |0      |None       |0 |
# |hourly                        |104|Intensity38              |INT       |0      |None       |0 |
# |hourly                        |105|Intensity39              |INT       |0      |None       |0 |
# |hourly                        |106|Intensity40              |INT       |0      |None       |0 |
# |hourly                        |107|Intensity41              |INT       |0      |None       |0 |
# |hourly                        |108|Intensity42              |INT       |0      |None       |0 |
# |hourly                        |109|Intensity43              |INT       |0      |None       |0 |
# |hourly                        |110|Intensity44              |INT       |0      |None       |0 |
# |hourly                        |111|Intensity45              |INT       |0      |None       |0 |
# |hourly                        |112|Intensity46              |INT       |0      |None       |0 |
# |hourly                        |113|Intensity47              |INT       |0      |None       |0 |
# |hourly                        |114|Intensity48              |INT       |0      |None       |0 |
# |hourly                        |115|Intensity49              |INT       |0      |None       |0 |
# |hourly                        |116|Intensity50              |INT       |0      |None       |0 |
# |hourly                        |117|Intensity51              |INT       |0      |None       |0 |
# |hourly                        |118|Intensity52              |INT       |0      |None       |0 |
# |hourly                        |119|Intensity53              |INT       |0      |None       |0 |
# |hourly                        |120|Intensity54              |INT       |0      |None       |0 |
# |hourly                        |121|Intensity55              |INT       |0      |None       |0 |
# |hourly                        |122|Intensity56              |INT       |0      |None       |0 |
# |hourly                        |123|Intensity57              |INT       |0      |None       |0 |
# |hourly                        |124|Intensity58              |INT       |0      |None       |0 |
# |hourly                        |125|Intensity59              |INT       |0      |None       |0 |
# |hourly                        |126|Steps00                  |INT       |0      |None       |0 |
# |hourly                        |127|Steps01                  |INT       |0      |None       |0 |
# |hourly                        |128|Steps02                  |INT       |0      |None       |0 |
# |hourly                        |129|Steps03                  |INT       |0      |None       |0 |
# |hourly                        |130|Steps04                  |INT       |0      |None       |0 |
# |hourly                        |131|Steps05                  |INT       |0      |None       |0 |
# |hourly                        |132|Steps06                  |INT       |0      |None       |0 |
# |hourly                        |133|Steps07                  |INT       |0      |None       |0 |
# |hourly                        |134|Steps08                  |INT       |0      |None       |0 |
# |hourly                        |135|Steps09                  |INT       |0      |None       |0 |
# |hourly                        |136|Steps10                  |INT       |0      |None       |0 |
# |hourly                        |137|Steps11                  |INT       |0      |None       |0 |
# |hourly                        |138|Steps12                  |INT       |0      |None       |0 |
# |hourly                        |139|Steps13                  |INT       |0      |None       |0 |
# |hourly                        |140|Steps14                  |INT       |0      |None       |0 |
# |hourly                        |141|Steps15                  |INT       |0      |None       |0 |
# |hourly                        |142|Steps16                  |INT       |0      |None       |0 |
# |hourly                        |143|Steps17                  |INT       |0      |None       |0 |
# |hourly                        |144|Steps18                  |INT       |0      |None       |0 |
# |hourly                        |145|Steps19                  |INT       |0      |None       |0 |
# |hourly                        |146|Steps20                  |INT       |0      |None       |0 |
# |hourly                        |147|Steps21                  |INT       |0      |None       |0 |
# |hourly                        |148|Steps22                  |INT       |0      |None       |0 |
# |hourly                        |149|Steps23                  |INT       |0      |None       |0 |
# |hourly                        |150|Steps24                  |INT       |0      |None       |0 |
# |hourly                        |151|Steps25                  |INT       |0      |None       |0 |
# |hourly                        |152|Steps26                  |INT       |0      |None       |0 |
# |hourly                        |153|Steps27                  |INT       |0      |None       |0 |
# |hourly                        |154|Steps28                  |INT       |0      |None       |0 |
# |hourly                        |155|Steps29                  |INT       |0      |None       |0 |
# |hourly                        |156|Steps30                  |INT       |0      |None       |0 |
# |hourly                        |157|Steps31                  |INT       |0      |None       |0 |
# |hourly                        |158|Steps32                  |INT       |0      |None       |0 |
# |hourly                        |159|Steps33                  |INT       |0      |None       |0 |
# |hourly                        |160|Steps34                  |INT       |0      |None       |0 |
# |hourly                        |161|Steps35                  |INT       |0      |None       |0 |
# |hourly                        |162|Steps36                  |INT       |0      |None       |0 |
# |hourly                        |163|Steps37                  |INT       |0      |None       |0 |
# |hourly                        |164|Steps38                  |INT       |0      |None       |0 |
# |hourly                        |165|Steps39                  |INT       |0      |None       |0 |
# |hourly                        |166|Steps40                  |INT       |0      |None       |0 |
# |hourly                        |167|Steps41                  |INT       |0      |None       |0 |
# |hourly                        |168|Steps42                  |INT       |0      |None       |0 |
# |hourly                        |169|Steps43                  |INT       |0      |None       |0 |
# |hourly                        |170|Steps44                  |INT       |0      |None       |0 |
# |hourly                        |171|Steps45                  |INT       |0      |None       |0 |
# |hourly                        |172|Steps46                  |INT       |0      |None       |0 |
# |hourly                        |173|Steps47                  |INT       |0      |None       |0 |
# |hourly                        |174|Steps48                  |INT       |0      |None       |0 |
# |hourly                        |175|Steps49                  |INT       |0      |None       |0 |
# |hourly                        |176|Steps50                  |INT       |0      |None       |0 |
# |hourly                        |177|Steps51                  |INT       |0      |None       |0 |
# |hourly                        |178|Steps52                  |INT       |0      |None       |0 |
# |hourly                        |179|Steps53                  |INT       |0      |None       |0 |
# |hourly                        |180|Steps54                  |INT       |0      |None       |0 |
# |hourly                        |181|Steps55                  |INT       |0      |None       |0 |
# |hourly                        |182|Steps56                  |INT       |0      |None       |0 |
# |hourly                        |183|Steps57                  |INT       |0      |None       |0 |
# |hourly                        |184|Steps58                  |INT       |0      |None       |0 |
# |hourly                        |185|Steps59                  |INT       |0      |None       |0 |
# |minuteNarrow                  |0  |Id                       |INT       |0      |None       |0 |
# |minuteNarrow                  |1  |ActivityMinute           |NUM       |0      |None       |0 |
# |minuteNarrow                  |2  |Calories                 |NUM       |0      |None       |0 |
# |minuteNarrow                  |3  |Intensity                |INT       |0      |None       |0 |
# |minuteNarrow                  |4  |METs                     |INT       |0      |None       |0 |
# |minuteNarrow                  |5  |Steps                    |INT       |0      |None       |0 |
# |minuteNarrow                  |6  |value                    |INT       |0      |None       |0 |
# |minuteNarrow                  |7  |logId                    |INT       |0      |None       |0 |
# |minuteWide                    |0  |Id                       |INT       |0      |None       |0 |
# |minuteWide                    |1  |ActivityHour             |NUM       |0      |None       |0 |
# |minuteWide                    |2  |Calories00               |NUM       |0      |None       |0 |
# |minuteWide                    |3  |Calories01               |NUM       |0      |None       |0 |
# |minuteWide                    |4  |Calories02               |NUM       |0      |None       |0 |
# |minuteWide                    |5  |Calories03               |NUM       |0      |None       |0 |
# |minuteWide                    |6  |Calories04               |NUM       |0      |None       |0 |
# |minuteWide                    |7  |Calories05               |NUM       |0      |None       |0 |
# |minuteWide                    |8  |Calories06               |NUM       |0      |None       |0 |
# |minuteWide                    |9  |Calories07               |NUM       |0      |None       |0 |
# |minuteWide                    |10 |Calories08               |NUM       |0      |None       |0 |
# |minuteWide                    |11 |Calories09               |NUM       |0      |None       |0 |
# |minuteWide                    |12 |Calories10               |NUM       |0      |None       |0 |
# |minuteWide                    |13 |Calories11               |NUM       |0      |None       |0 |
# |minuteWide                    |14 |Calories12               |NUM       |0      |None       |0 |
# |minuteWide                    |15 |Calories13               |NUM       |0      |None       |0 |
# |minuteWide                    |16 |Calories14               |NUM       |0      |None       |0 |
# |minuteWide                    |17 |Calories15               |NUM       |0      |None       |0 |
# |minuteWide                    |18 |Calories16               |NUM       |0      |None       |0 |
# |minuteWide                    |19 |Calories17               |NUM       |0      |None       |0 |
# |minuteWide                    |20 |Calories18               |NUM       |0      |None       |0 |
# |minuteWide                    |21 |Calories19               |NUM       |0      |None       |0 |
# |minuteWide                    |22 |Calories20               |NUM       |0      |None       |0 |
# |minuteWide                    |23 |Calories21               |NUM       |0      |None       |0 |
# |minuteWide                    |24 |Calories22               |NUM       |0      |None       |0 |
# |minuteWide                    |25 |Calories23               |NUM       |0      |None       |0 |
# |minuteWide                    |26 |Calories24               |NUM       |0      |None       |0 |
# |minuteWide                    |27 |Calories25               |NUM       |0      |None       |0 |
# |minuteWide                    |28 |Calories26               |NUM       |0      |None       |0 |
# |minuteWide                    |29 |Calories27               |NUM       |0      |None       |0 |
# |minuteWide                    |30 |Calories28               |NUM       |0      |None       |0 |
# |minuteWide                    |31 |Calories29               |NUM       |0      |None       |0 |
# |minuteWide                    |32 |Calories30               |NUM       |0      |None       |0 |
# |minuteWide                    |33 |Calories31               |NUM       |0      |None       |0 |
# |minuteWide                    |34 |Calories32               |NUM       |0      |None       |0 |
# |minuteWide                    |35 |Calories33               |NUM       |0      |None       |0 |
# |minuteWide                    |36 |Calories34               |NUM       |0      |None       |0 |
# |minuteWide                    |37 |Calories35               |NUM       |0      |None       |0 |
# |minuteWide                    |38 |Calories36               |NUM       |0      |None       |0 |
# |minuteWide                    |39 |Calories37               |NUM       |0      |None       |0 |
# |minuteWide                    |40 |Calories38               |NUM       |0      |None       |0 |
# |minuteWide                    |41 |Calories39               |NUM       |0      |None       |0 |
# |minuteWide                    |42 |Calories40               |NUM       |0      |None       |0 |
# |minuteWide                    |43 |Calories41               |NUM       |0      |None       |0 |
# |minuteWide                    |44 |Calories42               |NUM       |0      |None       |0 |
# |minuteWide                    |45 |Calories43               |NUM       |0      |None       |0 |
# |minuteWide                    |46 |Calories44               |NUM       |0      |None       |0 |
# |minuteWide                    |47 |Calories45               |NUM       |0      |None       |0 |
# |minuteWide                    |48 |Calories46               |NUM       |0      |None       |0 |
# |minuteWide                    |49 |Calories47               |NUM       |0      |None       |0 |
# |minuteWide                    |50 |Calories48               |NUM       |0      |None       |0 |
# |minuteWide                    |51 |Calories49               |NUM       |0      |None       |0 |
# |minuteWide                    |52 |Calories50               |NUM       |0      |None       |0 |
# |minuteWide                    |53 |Calories51               |NUM       |0      |None       |0 |
# |minuteWide                    |54 |Calories52               |NUM       |0      |None       |0 |
# |minuteWide                    |55 |Calories53               |NUM       |0      |None       |0 |
# |minuteWide                    |56 |Calories54               |NUM       |0      |None       |0 |
# |minuteWide                    |57 |Calories55               |NUM       |0      |None       |0 |
# |minuteWide                    |58 |Calories56               |NUM       |0      |None       |0 |
# |minuteWide                    |59 |Calories57               |NUM       |0      |None       |0 |
# |minuteWide                    |60 |Calories58               |NUM       |0      |None       |0 |
# |minuteWide                    |61 |Calories59               |NUM       |0      |None       |0 |
# |minuteWide                    |62 |Intensity00              |INT       |0      |None       |0 |
# |minuteWide                    |63 |Intensity01              |INT       |0      |None       |0 |
# |minuteWide                    |64 |Intensity02              |INT       |0      |None       |0 |
# |minuteWide                    |65 |Intensity03              |INT       |0      |None       |0 |
# |minuteWide                    |66 |Intensity04              |INT       |0      |None       |0 |
# |minuteWide                    |67 |Intensity05              |INT       |0      |None       |0 |
# |minuteWide                    |68 |Intensity06              |INT       |0      |None       |0 |
# |minuteWide                    |69 |Intensity07              |INT       |0      |None       |0 |
# |minuteWide                    |70 |Intensity08              |INT       |0      |None       |0 |
# |minuteWide                    |71 |Intensity09              |INT       |0      |None       |0 |
# |minuteWide                    |72 |Intensity10              |INT       |0      |None       |0 |
# |minuteWide                    |73 |Intensity11              |INT       |0      |None       |0 |
# |minuteWide                    |74 |Intensity12              |INT       |0      |None       |0 |
# |minuteWide                    |75 |Intensity13              |INT       |0      |None       |0 |
# |minuteWide                    |76 |Intensity14              |INT       |0      |None       |0 |
# |minuteWide                    |77 |Intensity15              |INT       |0      |None       |0 |
# |minuteWide                    |78 |Intensity16              |INT       |0      |None       |0 |
# |minuteWide                    |79 |Intensity17              |INT       |0      |None       |0 |
# |minuteWide                    |80 |Intensity18              |INT       |0      |None       |0 |
# |minuteWide                    |81 |Intensity19              |INT       |0      |None       |0 |
# |minuteWide                    |82 |Intensity20              |INT       |0      |None       |0 |
# |minuteWide                    |83 |Intensity21              |INT       |0      |None       |0 |
# |minuteWide                    |84 |Intensity22              |INT       |0      |None       |0 |
# |minuteWide                    |85 |Intensity23              |INT       |0      |None       |0 |
# |minuteWide                    |86 |Intensity24              |INT       |0      |None       |0 |
# |minuteWide                    |87 |Intensity25              |INT       |0      |None       |0 |
# |minuteWide                    |88 |Intensity26              |INT       |0      |None       |0 |
# |minuteWide                    |89 |Intensity27              |INT       |0      |None       |0 |
# |minuteWide                    |90 |Intensity28              |INT       |0      |None       |0 |
# |minuteWide                    |91 |Intensity29              |INT       |0      |None       |0 |
# |minuteWide                    |92 |Intensity30              |INT       |0      |None       |0 |
# |minuteWide                    |93 |Intensity31              |INT       |0      |None       |0 |
# |minuteWide                    |94 |Intensity32              |INT       |0      |None       |0 |
# |minuteWide                    |95 |Intensity33              |INT       |0      |None       |0 |
# |minuteWide                    |96 |Intensity34              |INT       |0      |None       |0 |
# |minuteWide                    |97 |Intensity35              |INT       |0      |None       |0 |
# |minuteWide                    |98 |Intensity36              |INT       |0      |None       |0 |
# |minuteWide                    |99 |Intensity37              |INT       |0      |None       |0 |
# |minuteWide                    |100|Intensity38              |INT       |0      |None       |0 |
# |minuteWide                    |101|Intensity39              |INT       |0      |None       |0 |
# |minuteWide                    |102|Intensity40              |INT       |0      |None       |0 |
# |minuteWide                    |103|Intensity41              |INT       |0      |None       |0 |
# |minuteWide                    |104|Intensity42              |INT       |0      |None       |0 |
# |minuteWide                    |105|Intensity43              |INT       |0      |None       |0 |
# |minuteWide                    |106|Intensity44              |INT       |0      |None       |0 |
# |minuteWide                    |107|Intensity45              |INT       |0      |None       |0 |
# |minuteWide                    |108|Intensity46              |INT       |0      |None       |0 |
# |minuteWide                    |109|Intensity47              |INT       |0      |None       |0 |
# |minuteWide                    |110|Intensity48              |INT       |0      |None       |0 |
# |minuteWide                    |111|Intensity49              |INT       |0      |None       |0 |
# |minuteWide                    |112|Intensity50              |INT       |0      |None       |0 |
# |minuteWide                    |113|Intensity51              |INT       |0      |None       |0 |
# |minuteWide                    |114|Intensity52              |INT       |0      |None       |0 |
# |minuteWide                    |115|Intensity53              |INT       |0      |None       |0 |
# |minuteWide                    |116|Intensity54              |INT       |0      |None       |0 |
# |minuteWide                    |117|Intensity55              |INT       |0      |None       |0 |
# |minuteWide                    |118|Intensity56              |INT       |0      |None       |0 |
# |minuteWide                    |119|Intensity57              |INT       |0      |None       |0 |
# |minuteWide                    |120|Intensity58              |INT       |0      |None       |0 |
# |minuteWide                    |121|Intensity59              |INT       |0      |None       |0 |
# |minuteWide                    |122|Steps00                  |INT       |0      |None       |0 |
# |minuteWide                    |123|Steps01                  |INT       |0      |None       |0 |
# |minuteWide                    |124|Steps02                  |INT       |0      |None       |0 |
# |minuteWide                    |125|Steps03                  |INT       |0      |None       |0 |
# |minuteWide                    |126|Steps04                  |INT       |0      |None       |0 |
# |minuteWide                    |127|Steps05                  |INT       |0      |None       |0 |
# |minuteWide                    |128|Steps06                  |INT       |0      |None       |0 |
# |minuteWide                    |129|Steps07                  |INT       |0      |None       |0 |
# |minuteWide                    |130|Steps08                  |INT       |0      |None       |0 |
# |minuteWide                    |131|Steps09                  |INT       |0      |None       |0 |
# |minuteWide                    |132|Steps10                  |INT       |0      |None       |0 |
# |minuteWide                    |133|Steps11                  |INT       |0      |None       |0 |
# |minuteWide                    |134|Steps12                  |INT       |0      |None       |0 |
# |minuteWide                    |135|Steps13                  |INT       |0      |None       |0 |
# |minuteWide                    |136|Steps14                  |INT       |0      |None       |0 |
# |minuteWide                    |137|Steps15                  |INT       |0      |None       |0 |
# |minuteWide                    |138|Steps16                  |INT       |0      |None       |0 |
# |minuteWide                    |139|Steps17                  |INT       |0      |None       |0 |
# |minuteWide                    |140|Steps18                  |INT       |0      |None       |0 |
# |minuteWide                    |141|Steps19                  |INT       |0      |None       |0 |
# |minuteWide                    |142|Steps20                  |INT       |0      |None       |0 |
# |minuteWide                    |143|Steps21                  |INT       |0      |None       |0 |
# |minuteWide                    |144|Steps22                  |INT       |0      |None       |0 |
# |minuteWide                    |145|Steps23                  |INT       |0      |None       |0 |
# |minuteWide                    |146|Steps24                  |INT       |0      |None       |0 |
# |minuteWide                    |147|Steps25                  |INT       |0      |None       |0 |
# |minuteWide                    |148|Steps26                  |INT       |0      |None       |0 |
# |minuteWide                    |149|Steps27                  |INT       |0      |None       |0 |
# |minuteWide                    |150|Steps28                  |INT       |0      |None       |0 |
# |minuteWide                    |151|Steps29                  |INT       |0      |None       |0 |
# |minuteWide                    |152|Steps30                  |INT       |0      |None       |0 |
# |minuteWide                    |153|Steps31                  |INT       |0      |None       |0 |
# |minuteWide                    |154|Steps32                  |INT       |0      |None       |0 |
# |minuteWide                    |155|Steps33                  |INT       |0      |None       |0 |
# |minuteWide                    |156|Steps34                  |INT       |0      |None       |0 |
# |minuteWide                    |157|Steps35                  |INT       |0      |None       |0 |
# |minuteWide                    |158|Steps36                  |INT       |0      |None       |0 |
# |minuteWide                    |159|Steps37                  |INT       |0      |None       |0 |
# |minuteWide                    |160|Steps38                  |INT       |0      |None       |0 |
# |minuteWide                    |161|Steps39                  |INT       |0      |None       |0 |
# |minuteWide                    |162|Steps40                  |INT       |0      |None       |0 |
# |minuteWide                    |163|Steps41                  |INT       |0      |None       |0 |
# |minuteWide                    |164|Steps42                  |INT       |0      |None       |0 |
# |minuteWide                    |165|Steps43                  |INT       |0      |None       |0 |
# |minuteWide                    |166|Steps44                  |INT       |0      |None       |0 |
# |minuteWide                    |167|Steps45                  |INT       |0      |None       |0 |
# |minuteWide                    |168|Steps46                  |INT       |0      |None       |0 |
# |minuteWide                    |169|Steps47                  |INT       |0      |None       |0 |
# |minuteWide                    |170|Steps48                  |INT       |0      |None       |0 |
# |minuteWide                    |171|Steps49                  |INT       |0      |None       |0 |
# |minuteWide                    |172|Steps50                  |INT       |0      |None       |0 |
# |minuteWide                    |173|Steps51                  |INT       |0      |None       |0 |
# |minuteWide                    |174|Steps52                  |INT       |0      |None       |0 |
# |minuteWide                    |175|Steps53                  |INT       |0      |None       |0 |
# |minuteWide                    |176|Steps54                  |INT       |0      |None       |0 |
# |minuteWide                    |177|Steps55                  |INT       |0      |None       |0 |
# |minuteWide                    |178|Steps56                  |INT       |0      |None       |0 |
# |minuteWide                    |179|Steps57                  |INT       |0      |None       |0 |
# |minuteWide                    |180|Steps58                  |INT       |0      |None       |0 |
# |minuteWide                    |181|Steps59                  |INT       |0      |None       |0 |

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Analysis Summary

# %% [markdown]
# ## Actions

# %% [markdown]
# ## Appendix
#
# ### Definitions
#
# ### Files Used
# | Description | File |
# | :---------- | :--: |
# | Jupyter notebook used for data concatenation, cleaning, and some feature engineering. | [Data_Concatenation.ipynb](https://github.com/hannankhan888/Data_Science_Portfolio/tree/main/Wellness_Tech_Company_Analysis_Case_Study/Data_Concatenation.ipynb) |
# | Folder containing large SQL queries used in this project. | [/SQL_queries/](https://github.com/hannankhan888/Data_Science_Portfolio/tree/main/Wellness_Tech_Company_Analysis_Case_Study/SQL_queries) |
# | This report in Jupyter notebook format. | [Wellness_Tech_Company_Analysis_Report.ipynb](https://github.com/hannankhan888/Data_Science_Portfolio/tree/main/Wellness_Tech_Company_Analysis_Case_Study/Wellness_Tech_Company_Analysis_Report.ipynb) |
